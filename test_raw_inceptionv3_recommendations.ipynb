# %% [markdown]
# Do PCA on VGG16 Output to see if similar watches are clustered together

# %%
import os

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2

from sklearn.metrics.pairwise import cosine_similarity
from keras.models import load_model

# %matplotlib inline

# %% [markdown]
# Open Relevant Files

# %%
f_vecs = np.load('inceptionv3_raw_feature_vectors.npy')
watch_names = pd.read_csv('inceptionv3_raw_feature_vectors_names.csv',index_col=0)

# %%
#watch_names = watch_names.iloc[:-1,:] #Excluded last model when running before

# %%
watch_names
# Out:
#                                                file_name
# 0      bracelet/TagHeuerCarreraCaliber5war215dbd0784.jpg
# 1      bracelet/BulgariSerpentiTubogas35mmsp35c7sds1t...
# 2      bracelet/RolexDayDate36mmYellowGoldDiamondBeze...
# 3      bracelet/ChopardImperialeQuartz36mm3885323004.jpg
# 4        bracelet/LonginesFlagshipAutomaticL48743377.jpg
# 5        bracelet/BreitlingChronomat44IB011012a696ss.jpg
# 6            bracelet/BreguetMarineRoyale5847br32rz0.jpg
# 7        bracelet/RaymondWeilToccata34mm5388sts97081.jpg
# 8      bracelet/RolexDatejust36mmStainlessSteel116234...
# 9      bracelet/BreitlingChronolinerm2431013bf02159m.jpg
# 10     bracelet/RolexDatejust41mmSteelandYellowGold12...
# 11                      bracelet/ChanelPremiereh3252.jpg
# 12     bracelet/OmegaDeVillePrestige327mm424103360520...
# 13     bracelet/BreitlingChronomat44GMTcb042012c858tt...
# 14        bracelet/BreitlingGalactic32c71356LAg704ss.jpg
# 15            bracelet/RaymondWeilNoemia5124sts00985.jpg
# 16     bracelet/AudemarsPiguetRoyalOakQuartz33mm67651...
# 17         bracelet/BulgariBzero1Quartz23mmbz23wsccm.jpg
# 18     bracelet/LonginesPrimaLunaQuartz265mmL81104876...
# 19     bracelet/RolexDatejust31mmStainlessSteelandRos...
# 20            bracelet/CartierBallonBleu36mmwe9005z3.jpg
# 21         bracelet/EbelEbelWaveAutomatic40mm1216333.jpg
# 22     bracelet/RolexLadyDatejust28mmStainlessSteelan...
# 23     bracelet/OmegaDeVillePrestige274mm424502760050...
# 24     bracelet/RolexDatejust31mmStainlessSteelandRos...
# 25     bracelet/RolexDayDate36mmEveroseGoldFlutedBeze...
# 26     bracelet/ChopardHappySportSquareQuartzSmall278...
# 27       bracelet/BreitlingChronomat44ab011012b956ss.jpg
# 28     bracelet/RolexDatejust41mmSteelandYellowGold12...
# 29     bracelet/RolexDayDate36mmWhiteGoldFlutedBezel1...
# ...                                                  ...
# 10427  strap/JaquetDrozLesAteliersdArtAutomataTHEBIRD...
# 10428                strap/JaquetDrozLady8j014503200.jpg
# 10429  strap/BreitlingBentley675Speeda4436412g814760p...
# 10430   strap/JaquetDrozAstraleEclipse43mmj012630240.jpg
# 10431    strap/BreitlingColtLady36mma7438911c913238s.jpg
# 10432         strap/BreguetTypeXXIFlyback3817stx23zu.jpg
# 10433  strap/BreitlingColtChronographa7338811bd431lt.jpg
# 10434     strap/HermesCapeCodQuartzSmallPM040269ww00.jpg
# 10435  strap/BreitlingTransoceanChronograph1461a19310...
# 10436  strap/ChopardHappySportRoundQuartz36mm27858260...
# 10437  strap/ZenithEliteChronographClassic03227240695...
# 10438     strap/BreitlingNavitimer01ab012012bb02437x.jpg
# 10439  strap/ZenithPilotMontredAeronefType20ExtraSpec...
# 10440    strap/HublotBigBangLinen41mm341XL2770NR1201.jpg
# 10441         strap/IWCPilotsWatchWorldtimerIW326201.jpg
# 10442  strap/GlashutteOriginalSenatorObserver10014050...
# 10443  strap/IWCPortugueseAutomaticChronographIW37144...
# 10444  strap/JaquetDrozGrandeSecondeCircled39mmj01401...
# 10445  strap/TagHeuerAquaracerAutomaticChronographcay...
# 10446  strap/OrisArtelierDate31mm01561768740510751470...
# 10447  strap/UlysseNardinMarineDiverChronographManufa...
# 10448  strap/UlysseNardinMarineDiverChronographManufa...
# 10449    strap/HermesCapeCodQuartzMediumGM043776ww00.jpg
# 10450  strap/AudemarsPiguetEdwardPiguetAutomatic15121...
# 10451              strap/LonginesEquestrianL61424712.jpg
# 10452      strap/BreitlingGalactic41a49350L2c8063lts.jpg
# 10453  strap/BreitlingAvengerIISeawolfa1733110f563109...
# 10454  strap/JaegerLeCoultreRendezVousNightDay29mm346...
# 10455  strap/BreitlingSuperoceanHeritageII46ab202033g...
# 10456     strap/LonginesHeritageChronographL27498722.jpg
#
# [10457 rows x 1 columns]

# %%
np.shape(f_vecs)
# Out:
# (10456, 2048)

# %% [markdown]
# Compute Cosine Similarities

# %%
dists = cosine_similarity(f_vecs)

# %%
np.shape(dists)
# Out:
# (10456, 10456)

# %%
dist_df = pd.DataFrame(data = dists)

# %%
dist_df.index = watch_names['file_name'].iloc[:-1]
dist_df.columns = watch_names['file_name'].iloc[:-1]

# %% [markdown]
# Function for finding n closest matches

# %%
def get_similar(watchs, n=None):
    """
    calculates which watchs are most similar to the watchs provided. Does not return
    the watchs that were provided
    
    Parameters
    ----------
    watchs: list
        some watchs!
    
    Returns
    -------
    ranked_watchs: list
        rank ordered watchs
    """
    watchs = [watch for watch in watchs if watch in dist_df.columns]
    watchs_summed = dist_df[watchs].apply(lambda row: np.sum(row), axis=1)
    watchs_summed = watchs_summed.sort_values(ascending=False)
    ranked_watchs = watchs_summed.index[watchs_summed.index.isin(watchs)==False]
    ranked_watchs = ranked_watchs.tolist()
    if n is None:
        return ranked_watchs
    else:
        return ranked_watchs[:n]

# %% [markdown]
# Random Image from Watch store Database

# %%
f_path = 'f_vec_data_padded/train/'
starting_name = np.random.choice(dist_df.index)
img=mpimg.imread(f_path + starting_name )
imgplot = plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 399.5, 399.5, -0.5)

# %% [markdown]
# Recommendations

# %%
n = 6
recommend_names = get_similar([starting_name],n=n)

r = int(np.ceil(n/2))
c = 2
plt.subplots(nrows=r, ncols=c,figsize=(12,20))

for ix, f_name in enumerate(recommend_names):
    plt.subplot(r,c,ix+1)
    img=mpimg.imread(f_path + f_name)
    imgplot = plt.imshow(img)
    plt.axis('off')

# %% [markdown]
# __What if the image isn't perfect__

# %% [markdown]
# First Load Model

# %%
model = load_model('inceptionv3_raw_2048.h5')
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/keras/models.py:251: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
def prepare_image(image_path):
    
    im = cv2.imread(image_path)
    im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
    im = cv2.resize(im, (299, 299)).astype(np.float32)
    im = im/255
#     im[:,:,0] -= 103.939
#     im[:,:,1] -= 116.779
#     im[:,:,2] -= 123.68
#    im = im.transpose((2,0,1))
    im = np.expand_dims(im, axis=0)
    return im

# %%
#img = prepare_image(f_path+starting_name)

# %%
test_path = 'test_pics/'
test_files = os.listdir(test_path) 
test_file = test_path + np.random.choice(test_files)
# test_file = test_path +'Bulgari-Octo-Finissimo-Automatic-Thinnest-Titanium-Sand-Blasted-2017-aBlogtoWatch-22.jpg'
#test_file = test_path +'cocktail_watch.JPG'
#test_file = test_path +'james_bonds_wrist.png'
#test_file = test_path +'ga054-omega-seamaster-planet-ocean-skyfall.jpg'

# %%
img2show=mpimg.imread(test_file)
imgplot = plt.imshow(img2show)
plt.axis('off')
# Out:
# (-0.5, 319.5, 239.5, -0.5)

# %%
img = prepare_image(test_file)
out = model.predict(img)
similarities = cosine_similarity(out,f_vecs) 
top_matches = np.array(similarities).argpartition(-n)[0][-n:]

# %%
recommend_names = dist_df.columns[top_matches]

r = int(np.ceil(n/2))
c = 2
plt.subplots(nrows=r, ncols=c,figsize=(12,20))

for ix, f_name in enumerate(recommend_names):
    plt.subplot(r,c,ix+1)
    img=mpimg.imread(f_path + f_name)
    imgplot = plt.imshow(img)
    plt.axis('off')
